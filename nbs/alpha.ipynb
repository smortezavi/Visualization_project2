# %% [markdown]
# ### By: Siavash Mortezavi, Daniel Grzenda

# %% [markdown]
# ## Imports

# %%
import plotly
# Create an account with plotly and make a useranme and get api key
plotly.tools.set_credentials_file(username='jigull', api_key='0ENaPTtHlDwDDYZxFwHo')

# %%
import pandas as pd
import numpy as np
import datetime as datetime
import plotly.plotly as py
import plotly.figure_factory as ff
import plotly.graph_objs as go
from plotly.graph_objs import *
# %matplotlib inline

# %% [markdown]
# ## We have all data required and it's stored at the following drop box Link
#
# https://www.dropbox.com/sh/hl5b7y4kzui3w6a/AACMwNfEkIAxi0Gfpxcy2Q5wa?dl=0

# %% [markdown]
# ## Sample Data and graphs

# %%
# Dow prices and Eur-Usd prices

Dow_prices = pd.read_csv('/Users/siavashmortezavi/Dropbox/Historical Prices/Dow_HistoricalPrices.csv')
Eur_Usd_prices = pd.read_excel('/Users/siavashmortezavi/Dropbox/Historical Prices/Eur:Usd.xlsx')

# %%
Dow_prices
# Out:
#          Date      Open      High       Low     Close
# 0    03/27/18  24276.62  24446.22  23708.73  23857.71
# 1    03/26/18  23825.74  24232.30  23741.22  24202.60
# 2    03/23/18  23995.18  24108.47  23509.06  23533.20
# 3    03/22/18  24526.01  24526.01  23938.74  23957.89
# 4    03/21/18  24723.49  24977.65  24655.40  24682.31
# 5    03/20/18  24650.64  24803.61  24650.64  24727.27
# 6    03/19/18  24893.69  24893.69  24453.14  24610.91
# 7    03/16/18  24877.34  25031.00  24857.09  24946.51
# 8    03/15/18  24837.29  25053.87  24753.29  24873.66
# 9    03/14/18  25086.97  25130.12  24668.83  24758.12
# 10   03/13/18  25257.75  25376.40  24947.50  25007.03
# 11   03/12/18  25372.44  25449.15  25152.02  25178.61
# 12   03/09/18  25004.89  25336.33  25004.89  25335.74
# 13   03/08/18  24853.41  24950.49  24703.05  24895.21
# 14   03/07/18  24758.15  24849.68  24535.12  24801.36
# 15   03/06/18  24965.89  24995.24  24708.41  24884.12
# ...

# %%
Eur_Usd_prices.head()
# Out:
#         Date   Price    Open    High     Low  Change %
# 0 2018-03-27  1.2403  1.2444  1.2478  1.2373   -0.0032
# 1 2018-03-26  1.2443  1.2348  1.2462  1.2340    0.0072
# 2 2018-03-25  1.2354  1.2351  1.2368  1.2351    0.0001
# 3 2018-03-23  1.2353  1.2302  1.2375  1.2301    0.0041
# 4 2018-03-22  1.2302  1.2338  1.2389  1.2285   -0.0029

# %%
Dow_prices.columns
# Out:
# Index(['Date', ' Open', ' High', ' Low', ' Close'], dtype='object')

# %%
## Time Series Plot with datetime Objects

df = Dow_prices
data = [go.Scatter(x=df.Date, y = df[' Close'])]
py.iplot(data, filename = 'Arson')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~jigull/5.embed" height="525px" width="100%"></iframe>

# %%
## Time Series Plot with datetime Objects

df = Eur_Usd_prices
data = [go.Scatter(x=df.Date, y = df['Price'])]
py.iplot(data, filename = 'Arson')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~jigull/5.embed" height="525px" width="100%"></iframe>
